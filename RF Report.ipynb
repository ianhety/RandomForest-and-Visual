# %% [markdown]
# # RandomForest Summary

# %% [markdown]
# # Step1 Data Import
#
# The data we used is data.xlsx which includes 30969 samples and 65 features.
# Here is a summary of these features about the NULL values.

# %%
Nullsummary
# Out:
#                                   variable type  Number of null  \
# Patient_DB_ID                                ID               0
# Procedure_Unique_Identifier                  ID               0
# Procedure Year                      Numeric_int               0
# Procedure Quarter of year           categorical               0
# Procedure Month                     categorical               0
# Procedure MonthNumber               Numeric_int               0
# Procedure Week of year              Categorical               0
# Procedure Day of Month              Numeric_int               0
# Day of Week                         Categorical               0
# Time Waiting for Procedure          Categorical            9281
# Procedure Group                     Categorical               0
# Procedure TypeI                     Categorical               0
# Booked Procedure                    Categorical               1
# PREVIOUS_MI                         Categorical            8601
# PREVIOUS_CABG                       Categorical            8601
# PREVIOUS_PCI                        Categorical            8601
# RENAL_DISEASE                       Categorical            8601
# HISTORY_HYPERTENSION                Categorical           30969
# FAMILY_HIST_CAD                     Categorical            8601
# EJECTION_FRACTION                   Numeric_int           26288
# EJECTION_FRACTION_CAT               Categorical           11550
# TOTAL_CHOLESTEROL                 Numeric_float           24364
# HEIGHT                            Numeric_float           20379
# WEIGHT                            Numeric_float           19497
# BMI                               Numeric_float           20402
# DIABETES_TYPE                       Categorical            9141
# DIABETES_CONTROL                    Categorical           30717
# Smoker                              Categorical           10590
# HEART_RATE                          Numeric_int           24477
# Euroscore                           Numeric_int           30842
# CLINICAL_SYNDROME                   Categorical           16095
# Indication for intervention         Categorical           16189
# ACS                                 Categorical           14360
# Presenting ECG                      Categorical           22456
# Thrombolysis                        Categorical           22458
# COMPLICATION                        Categorical           29518
# ACCESS_TYPE                         Categorical            4339
# ACCESS_SITE                         Categorical            4339
# ACCESS_METHOD                       Categorical            4339
# CATH EVENTS                         Categorical           14345
# Radiation Dose                      Numeric_int            2423
# Replacement Device?                 Categorical           28541
# Replacement Reason                  Categorical           30713
#  Procedure typeII                   Categorical           28549
# Device type                         Categorical           28549
# Device type.1                       Categorical           28549
# ARRHYTHMIA?                         Categorical               0
# No. of Ablations?                   Numeric_int               0
# No. Vessels Attempted               Numeric_int           16095
# No. Chronic Occlusions Attempted    Numeric_int           16730
# No. Lesions Attempted               Numeric_int           16673
# No. Lesions Successful              Numeric_int           16748
# Largest balloon/Stent Used        Numeric_float           16987
# No. of Restenosis attempted         Numeric_int           16856
# No. Instent restenosis attempted    Numeric_int           16864
# No. Stents Used                     Numeric_int           16806
# No. Drug Eluting Stents Used        Numeric_int           16833
# Longest Stent/Treated segment       Numeric_int           17058
# Indication for stent                Categorical           30964
# LMS Protected                       Categorical           30964
# OUTCOME                             Categorical           10395
# LENGTH_STAY_PROC_TO_DISCH           Numeric_int           30487
# GENDER                              Categorical               0
# Age                                 Numeric_int               0
# Ethnicity                           Categorical             886
#
#                                                                               Items
# Patient_DB_ID                     [1260432, 1260597, 1260621, 1260672, 1259543, ...
# Procedure_Unique_Identifier       [243848, 243867, 243871, 243881, 242629, 24263...
# Procedure Year                                 [2012, 2011, 2010, 2013, 2015, 2014]
# Procedure Quarter of year                                  ['Q4', 'Q1', 'Q3', 'Q2']
# Procedure Month                   ['November', 'October', 'January', 'February',...
# Procedure MonthNumber                       [11, 10, 1, 2, 8, 9, 3, 5, 6, 4, 12, 7]
# Procedure Week of year            [' Week 46', ' Week 45', ' Week 47', ' Week 43...
# Procedure Day of Month            [12, 8, 21, 7, 27, 28, 6, 31, 4, 10, 29, 30, 1...
# Day of Week                       ['Monday', 'Thursday', 'Wednesday', 'Saturday'...
# Time Waiting for Procedure        ['Within 1 week', 'Within 2 weeks', 'Within 3 ...
# Procedure Group                               ['[Catheter]', '[Electrophysiology]']
# Procedure TypeI                   ['[Catheter Lab Diagnostic]', '[Pacing &amp; I...
# Booked Procedure                  ['[PCI standard]', '[Left Heart Catheter  PCI]...
# PREVIOUS_MI                                           ['No', 'Unknown', 'Yes', nan]
# PREVIOUS_CABG                                         ['No', 'Unknown', 'Yes', nan]
# PREVIOUS_PCI                                          ['No', 'Unknown', 'Yes', nan]
# RENAL_DISEASE                     ['Creatinine 140 - 200 umol/L', 'Creatinine &g...
# HISTORY_HYPERTENSION                                                          [nan]
# FAMILY_HIST_CAD                                       ['No', 'Unknown', 'Yes', nan]
# EJECTION_FRACTION                 [nan, 35.0, 55.0, 40.0, 60.0, 50.0, 38.0, 1.0,...
# EJECTION_FRACTION_CAT             ['Good (LVEF &gt; 50%)', 'Unknown', 'Moderate ...
# TOTAL_CHOLESTEROL                 [nan, 4.3, 3.9, 3.4, 4.5, 5, 6, 3.1, 4.4, 7.1,...
# HEIGHT                            [nan, 1.5, 1.76, 1.8999999999999999, 1.73, 1.7...
# WEIGHT                            [nan, 102.0, 75.0, 95.0, 97.5, 70.0, 77.0, 68....
# BMI                               [nan, 45.329999999999998, 24.210000000000001, ...
# DIABETES_TYPE                     ['Not Diabetic', 'Unknown - data missing', nan...
# DIABETES_CONTROL                                                   [nan, 'Insulin']
# Smoker                            ['No', 'Yes', 'Ex Smoker', 'Unknown', nan, 'Oc...
# HEART_RATE                        [nan, 60.0, 56.0, 63.0, 62.0, 68.0, 114.0, 74....
# Euroscore                         [nan, 6.0, 3.0, 4.0, 0.0, 5.0, 1.0, 2.0, 7.0, ...
# CLINICAL_SYNDROME                 ['Acute Coronary Syndrome (ACS/AMI)', 'Stable'...
# Indication for intervention       ['ACS - UA, NSTEMI or convalescent STEMI', 'St...
# ACS                                                   ['YES', 'Unknown', nan, 'NO']
# Presenting ECG                    ['Normal Sinus Rhythm', 'T wave changes', nan,...
# Thrombolysis                      ['No', nan, 'Yes &lt; 1 day', 'Unknown', 'Yes ...
# COMPLICATION                      [nan, 'Asystolic Episode during procedure', '0...
# ACCESS_TYPE                       ['Arterial', 'Arterial;Arterial', nan, 'Arteri...
# ACCESS_SITE                       ['RRA', 'RFA', 'RRA;RFA', nan, 'RFA;RFV', 'RFA...
# ACCESS_METHOD                     ['Percutaneous', 'Percutaneous;Percutaneous', ...
# CATH EVENTS                       ['Balloon - Compliant, Abbott vascular, TREK B...
# Radiation Dose                    [5147.0, 5798.0, 9762.0, 58500.0, 4845.0, 3064...
# Replacement Device?                                            [nan, 'N', 'F', 'T']
# Replacement Reason                [nan, 'Normal EOL', 'Expected battery depletio...
#  Procedure typeII                 [nan, 'ICD', 'Permanent pacemaker', 'Loop reco...
# Device type                       [nan, 'Dual chamber', 'Single chamber', 'Bi-ve...
# Device type.1                        [nan, 'Sub-rectus', 'Unknown', 'Supra-rectus']
# ARRHYTHMIA?                       ['[Arrhythmia Type]:[None]', '[Arrhythmia Type...
# No. of Ablations?                                                      [0, 1, 2, 3]
# No. Vessels Attempted                      [1.0, nan, 2.0, 6.0, 3.0, 0.0, 4.0, 5.0]
# No. Chronic Occlusions Attempted                     [0.0, nan, 1.0, 2.0, 4.0, 3.0]
# No. Lesions Attempted                      [1.0, nan, 2.0, 0.0, 3.0, 4.0, 5.0, 6.0]
# No. Lesions Successful            [1.0, nan, 0.0, 2.0, 3.0, 4.0, 275.0, 5.0, 235...
# Largest balloon/Stent Used        [2.5, 3.5, 3.0, 4.0, nan, 2.0, 2.75, 2.25, 3.2...
# No. of Restenosis attempted              [23.0, 0.0, nan, 1.0, 2.0, 3.0, 24.0, 9.0]
# No. Instent restenosis attempted                     [0.0, nan, 1.0, 2.0, 3.0, 9.0]
# No. Stents Used                   [1.0, 2.0, nan, 0.0, 4.0, 3.0, 5.0, 6.0, 7.0, ...
# No. Drug Eluting Stents Used      [1.0, 2.0, 0.0, nan, 4.0, 3.0, 15.0, 5.0, 6.0,...
# Longest Stent/Treated segment     [23.0, 16.0, 44.0, 18.0, 41.0, 28.0, nan, 24.0...
# Indication for stent                                 [nan, 'Stent used - Elective']
# LMS Protected                                                          [nan, 'Yes']
# OUTCOME                                           ['Alive', 'Dead', nan, 'Unknown']
# LENGTH_STAY_PROC_TO_DISCH         [nan, 9.0, 68.0, 4.0, 0.0, 67.0, 6.0, 100.0, 7...
# GENDER                                                ['Male', 'Female', 'Unknown']
# Age                               [52, 53, 51, 83, 77, 67, 48, 69, 86, 60, 79, 5...
# Ethnicity                         ['White British', 'White', nan, 'Not stated', ...

# %% [markdown]
# # Step2 Transform data
#
# Depending on the number of Null, we delete the features which include so many null values (number >= 20000).
#
# For categorical feature, we treated the null value as a new categorical 0. For numerical feature, we
# replace the null value with the mean of the total values.
#
# The data after transform looks as following:

# %%
data
# Out:
#        Procedure Year  Procedure Quarter of year  Procedure Month  \
# 0              2012.0                          3                9
# 1              2012.0                          3                9
# 2              2012.0                          3                9
# 3              2012.0                          3                9
# 4              2012.0                          3               10
# 5              2012.0                          3               10
# 6              2012.0                          3               10
# 7              2012.0                          3               10
# 8              2012.0                          3               10
# 9              2012.0                          3               10
# ...               ...                        ...              ...
# 30959          2015.0                          3                2
# 30960          2015.0                          3                2
# 30961          2015.0                          3                2
# 30962          2015.0                          3                2
# 30963          2015.0                          3                2
# 30964          2015.0                          3                2
# 30965          2015.0                          3                2
# 30966          2015.0                          3                2
# 30967          2015.0                          3                2
# 30968          2015.0                          3                2
#
#        Procedure MonthNumber  Procedure Week of year  Procedure Day of Month  \
# 0                       11.0                      40                    12.0
# 1                       11.0                      39                     8.0
# 2                       11.0                      41                    21.0
# 3                       11.0                      39                     7.0
# 4                       10.0                      37                    27.0
# 5                       10.0                      37                    27.0
# 6                       10.0                      38                    28.0
# 7                       10.0                      38                    28.0
# 8                       10.0                      38                    28.0
# 9                       10.0                      38                    28.0
# ...                      ...                     ...                     ...
# 30959                   12.0                      48                    31.0
# 30960                   12.0                      48                    31.0
# 30961                   12.0                      48                    30.0
# 30962                   12.0                      48                    31.0
# 30963                   12.0                      46                    13.0
# 30964                   12.0                      46                    13.0
# 30965                   12.0                      46                    13.0
# 30966                   12.0                      46                    13.0
# 30967                   12.0                      46                    14.0
# 30968                   12.0                      46                    14.0
#
#        Day of Week  Time Waiting for Procedure  Procedure Group  \
# 0                1                           7                0
# 1                4                           7                0
# 2                6                           8                0
# 3                6                           9                0
# 4                2                           9                0
# 5                2                           7                0
# 6                3                           7                0
# 7                3                           7                0
# 8                3                           7                0
# 9                3                           7                0
# ...            ...                         ...              ...
# 30959            4                           7                0
# 30960            4                           7                0
# 30961            6                           0                0
# 30962            4                           7                0
# 30963            3                           0                0
# 30964            3                           0                0
# 30965            3                           0                0
# 30966            3                           7                0
# 30967            1                           7                0
# 30968            1                           0                1
#
#        Procedure TypeI  Booked Procedure  PREVIOUS_MI  PREVIOUS_CABG  \
# 0                    1               165            1              1
# 1                    1               129            1              1
# 2                    1               165            1              1
# 3                    1               129            2              2
# 4                    1               129            1              1
# 5                    1               129            3              3
# 6                    1               129            1              1
# 7                    1               129            2              2
# 8                    1               129            1              1
# 9                    1               129            1              1
# ...                ...               ...          ...            ...
# 30959                1               151            3              3
# 30960                1               151            1              1
# 30961                1               129            1              1
# 30962                1               151            1              1
# 30963                1               129            1              1
# 30964                1                37            1              1
# 30965                1               129            3              3
# 30966                1               129            1              1
# 30967                1               165            1              1
# 30968                2                54            0              0
#
#        PREVIOUS_PCI  RENAL_DISEASE  FAMILY_HIST_CAD  EJECTION_FRACTION_CAT  \
# 0                 1              2                1                      1
# 1                 1              2                1                      1
# 2                 1              2                1                      1
# 3                 2              1                2                      6
# 4                 1              2                1                      6
# 5                 3              3                3                      3
# 6                 1              2                1                      5
# 7                 2              1                2                      1
# 8                 1              2                1                      3
# 9                 1              2                1                      6
# ...             ...            ...              ...                    ...
# 30959             3              3                3                      1
# 30960             1              2                1                      3
# 30961             1              2                1                      6
# 30962             1              2                1                      1
# 30963             1              2                1                      1
# 30964             1              2                1                      1
# 30965             3              3                3                      6
# 30966             1              2                1                      3
# 30967             1              2                1                      1
# 30968             0              0                0                      0
#
#               BMI  DIABETES_TYPE  DIABETES_CONTROL  Smoker  ACS  ACCESS_TYPE  \
# 0      4902.49929              3                 0       3    3            1
# 1      4902.49929              3                 0       7    3            1
# 2        45.33000              3                 0       1    2            1
# 3      4902.49929             10                 0       6    3            1
# 4      4902.49929              3                 0       3    3            1
# 5        24.21000              3                 0       3    3            1
# 6      4902.49929              3                 0       7    3            1
# 7        28.25000              3                 0       6    0            1
# 8      4902.49929              3                 0       1    3            2
# 9      4902.49929              3                 0       7    3            2
# ...           ...            ...               ...     ...  ...          ...
# 30959  4902.49929              0                 0       0    0            1
# 30960  4902.49929              6                 0       6    0            1
# 30961    23.53000              3                 0       0    3            1
# 30962    25.95000              7                 0       3    0            1
# 30963  4902.49929              3                 0       3    0            1
# 30964    30.93000              3                 0       3    3            1
# 30965    26.23000              6                 0       3    3            1
# 30966    19.53000              3                 0       6    2            1
# 30967  4902.49929              3                 0       0    2            1
# 30968  4902.49929              0                 0       0    0            0
#
#        ACCESS_SITE  ACCESS_METHOD  Radiation Dose   Procedure typeII  \
# 0               69              3          5147.0                  0
# 1               69              3          5798.0                  0
# 2               69              3          9762.0                  0
# 3               69              3         58500.0                  0
# 4               35              3          4845.0                  0
# 5               35              3          3064.0                  0
# 6               69              3          4153.0                  0
# 7               69              3          8978.0                  0
# 8               79              5          6312.0                  0
# 9               79              5          6521.0                  0
# ...            ...            ...             ...                ...
# 30959           35              3          1649.0                  0
# 30960           35              3          3399.0                  0
# 30961           35              3          2394.0                  0
# 30962           69              3          2411.0                  0
# 30963           69              3          2556.0                  0
# 30964           69              3         11316.0                  0
# 30965           69              3          3734.0                  0
# 30966           69              3          3920.0                  0
# 30967           69              3          9726.0                  0
# 30968            0              0           451.0                  3
#
#        ARRHYTHMIA?  No. of Ablations?  No. Vessels Attempted  \
# 0               32                0.0               1.000000
# 1               32                0.0               1.000000
# 2               32                0.0               1.000000
# 3               32                0.0               1.000000
# 4               32                0.0               1.000000
# 5               32                0.0               1.000000
# 6               32                0.0               1.000000
# 7               32                0.0               1.232419
# 8               32                0.0               1.000000
# 9               32                0.0               1.000000
# ...            ...                ...                    ...
# 30959           32                0.0               1.232419
# 30960           32                0.0               1.232419
# 30961           32                0.0               1.000000
# 30962           32                0.0               1.232419
# 30963           32                0.0               1.232419
# 30964           32                0.0               2.000000
# 30965           32                0.0               1.000000
# 30966           32                0.0               1.000000
# 30967           32                0.0               2.000000
# 30968           32                0.0               1.232419
#
#        No. Chronic Occlusions Attempted  No. Lesions Attempted  \
# 0                              0.000000               1.000000
# 1                              0.000000               1.000000
# 2                              0.000000               1.000000
# 3                              0.000000               1.000000
# 4                              0.000000               1.000000
# 5                              0.000000               1.000000
# 6                              0.000000               1.000000
# 7                              0.077323               1.281337
# 8                              0.000000               1.000000
# 9                              0.000000               1.000000
# ...                                 ...                    ...
# 30959                          0.077323               1.281337
# 30960                          0.077323               1.281337
# 30961                          0.000000               1.000000
# 30962                          0.077323               1.281337
# 30963                          0.077323               1.281337
# 30964                          0.000000               3.000000
# 30965                          0.077323               1.281337
# 30966                          0.000000               1.000000
# 30967                          0.000000               3.000000
# 30968                          0.077323               1.281337
#
#        No. Lesions Successful  Largest balloon/Stent Used  \
# 0                    1.000000                    2.500000
# 1                    1.000000                    3.500000
# 2                    1.000000                    3.000000
# 3                    1.000000                    3.500000
# 4                    1.000000                    3.500000
# 5                    1.000000                    4.000000
# 6                    1.000000                    3.000000
# 7                    1.362211                    3.226638
# 8                    0.000000                    2.000000
# 9                    1.000000                    3.000000
# ...                       ...                         ...
# 30959                1.362211                    3.226638
# 30960                1.362211                    3.226638
# 30961                1.000000                    3.500000
# 30962                1.362211                    3.226638
# 30963                1.362211                    3.226638
# 30964                3.000000                   24.000000
# 30965                1.362211                    3.226638
# 30966                1.000000                    2.500000
# 30967                3.000000                    3.000000
# 30968                1.362211                    3.226638
#
#        No. of Restenosis attempted  No. Instent restenosis attempted  \
# 0                        23.000000                          0.000000
# 1                         0.000000                          0.000000
# 2                         0.000000                          0.000000
# 3                         0.000000                          0.000000
# 4                         0.000000                          0.000000
# 5                         0.000000                          0.000000
# 6                         0.000000                          0.000000
# 7                         0.030398                          0.042255
# 8                         0.000000                          0.000000
# 9                         0.000000                          0.000000
# ...                            ...                               ...
# 30959                     0.030398                          0.042255
# 30960                     0.030398                          0.042255
# 30961                     0.000000                          0.000000
# 30962                     0.030398                          0.042255
# 30963                     0.030398                          0.042255
# 30964                     0.000000                          0.000000
# 30965                     0.030398                          0.042255
# 30966                     0.000000                          0.000000
# 30967                     0.000000                          0.000000
# 30968                     0.030398                          0.042255
#
#        No. Stents Used  No. Drug Eluting Stents Used  \
# 0             1.000000                      1.000000
# 1             1.000000                      1.000000
# 2             2.000000                      2.000000
# 3             1.000000                      1.000000
# 4             2.000000                      0.000000
# 5             1.000000                      0.000000
# 6             1.000000                      1.000000
# 7             1.375697                      1.212153
# 8             0.000000                      0.000000
# 9             1.000000                      1.000000
# ...                ...                           ...
# 30959         1.375697                      1.212153
# 30960         1.375697                      1.212153
# 30961         1.000000                      1.000000
# 30962         1.375697                      1.212153
# 30963         1.375697                      1.212153
# 30964         3.000000                      3.000000
# 30965         1.375697                      1.212153
# 30966         1.000000                      1.000000
# 30967         3.000000                      3.000000
# 30968         1.375697                      1.212153
#
#        Longest Stent/Treated segment  OUTCOME  GENDER   Age  Ethnicity
# 0                          23.000000        1       1  52.0         17
# 1                          16.000000        1       1  53.0         17
# 2                          44.000000        1       0  51.0         17
# 3                          18.000000        2       1  83.0         17
# 4                          41.000000        1       1  77.0         17
# 5                          28.000000        1       1  67.0         17
# 6                          18.000000        1       1  48.0         17
# 7                          22.275609        1       1  69.0         17
# 8                          22.275609        1       0  86.0         17
# 9                          24.000000        1       1  60.0         17
# ...                              ...      ...     ...   ...        ...
# 30959                      22.275609        1       1  87.0         17
# 30960                      22.275609        1       1  46.0         17
# 30961                      16.000000        0       0  75.0         13
# 30962                      22.275609        1       1  47.0         13
# 30963                      22.275609        0       1  79.0         17
# 30964                       3.000000        0       1  45.0         17
# 30965                      22.275609        0       1  78.0         13
# 30966                      20.000000        2       0  97.0         13
# 30967                      16.000000        1       1  47.0         17
# 30968                      22.275609        0       0  81.0         17
#
# [30969 rows x 43 columns]

# %% [markdown]
# # Step3 Balance Outcome
#
# Since the OUTCOME is unbalanced, which has 253 of Dead and 20295 of Alive. We need oversampling and
# undersampling to control each outcome with 1265 rows.
#
# Oversampling: copy the data for five times.
# Undersampling: choose the first 1265 rows of Alive
#
# results as following:

# %%
data_new
# Out:
#        Procedure Year  Procedure Quarter of year  Procedure Month  \
# 0              2012.0                          3                9
# 1              2012.0                          3                9
# 2              2012.0                          3                9
# 4              2012.0                          3               10
# 5              2012.0                          3               10
# 6              2012.0                          3               10
# 7              2012.0                          3               10
# 8              2012.0                          3               10
# 9              2012.0                          3               10
# 11             2012.0                          3                9
# ...               ...                        ...              ...
# 29282          2015.0                          1                6
# 29567          2015.0                          2                5
# 29644          2015.0                          2                1
# 29822          2015.0                          2                5
# 29871          2015.0                          2                5
# 30071          2015.0                          2                1
# 30298          2015.0                          2                1
# 30560          2015.0                          2               11
# 30941          2015.0                          3                9
# 30966          2015.0                          3                2
#
#        Procedure MonthNumber  Procedure Week of year  Procedure Day of Month  \
# 0                       11.0                      40                    12.0
# 1                       11.0                      39                     8.0
# 2                       11.0                      41                    21.0
# 4                       10.0                      37                    27.0
# 5                       10.0                      37                    27.0
# 6                       10.0                      38                    28.0
# 7                       10.0                      38                    28.0
# 8                       10.0                      38                    28.0
# 9                       10.0                      38                    28.0
# 11                      11.0                      39                     7.0
# ...                      ...                     ...                     ...
# 29282                    6.0                      18                    25.0
# 29567                    7.0                      24                    29.0
# 29644                    8.0                      27                    17.0
# 29822                    7.0                      24                    27.0
# 29871                    7.0                      24                    29.0
# 30071                    8.0                      26                    11.0
# 30298                    8.0                      28                    28.0
# 30560                    9.0                      30                    11.0
# 30941                   11.0                      42                    27.0
# 30966                   12.0                      46                    13.0
#
#        Day of Week  Time Waiting for Procedure  Procedure Group  \
# 0                1                           7                0
# 1                4                           7                0
# 2                6                           8                0
# 4                2                           9                0
# 5                2                           7                0
# 6                3                           7                0
# 7                3                           7                0
# 8                3                           7                0
# 9                3                           7                0
# 11               6                           8                0
# ...            ...                         ...              ...
# 29282            4                           7                0
# 29567            6                           7                0
# 29644            1                           7                0
# 29822            1                           7                0
# 29871            6                           7                0
# 30071            5                           7                0
# 30298            0                           7                0
# 30560            0                           7                0
# 30941            0                           8                0
# 30966            3                           7                0
#
#        Procedure TypeI  Booked Procedure  PREVIOUS_MI  PREVIOUS_CABG  \
# 0                    1               165            1              1
# 1                    1               129            1              1
# 2                    1               165            1              1
# 4                    1               129            1              1
# 5                    1               129            3              3
# 6                    1               129            1              1
# 7                    1               129            2              2
# 8                    1               129            1              1
# 9                    1               129            1              1
# 11                   1               165            1              1
# ...                ...               ...          ...            ...
# 29282                1               129            1              1
# 29567                1               129            1              1
# 29644                1               129            1              1
# 29822                1               129            1              1
# 29871                1               129            3              3
# 30071                1               129            2              2
# 30298                1               165            3              3
# 30560                1               129            1              1
# 30941                1               129            3              3
# 30966                1               129            1              1
#
#        PREVIOUS_PCI  RENAL_DISEASE  FAMILY_HIST_CAD  EJECTION_FRACTION_CAT  \
# 0                 1              2                1                      1
# 1                 1              2                1                      1
# 2                 1              2                1                      1
# 4                 1              2                1                      6
# 5                 3              3                3                      3
# 6                 1              2                1                      5
# 7                 2              1                2                      1
# 8                 1              2                1                      3
# 9                 1              2                1                      6
# 11                1              2                1                      1
# ...             ...            ...              ...                    ...
# 29282             1              2                1                      6
# 29567             1              2                1                      6
# 29644             1              2                1                      1
# 29822             1              2                1                      5
# 29871             3              3                3                      6
# 30071             2              1                2                      3
# 30298             3              3                3                      3
# 30560             1              2                1                      0
# 30941             3              3                3                      5
# 30966             1              2                1                      3
#
#               BMI  DIABETES_TYPE  DIABETES_CONTROL  Smoker  ACS  ACCESS_TYPE  \
# 0      4902.49929              3                 0       3    3            1
# 1      4902.49929              3                 0       7    3            1
# 2        45.33000              3                 0       1    2            1
# 4      4902.49929              3                 0       3    3            1
# 5        24.21000              3                 0       3    3            1
# 6      4902.49929              3                 0       7    3            1
# 7        28.25000              3                 0       6    0            1
# 8      4902.49929              3                 0       1    3            2
# 9      4902.49929              3                 0       7    3            2
# 11       31.74000              3                 0       1    2            1
# ...           ...            ...               ...     ...  ...          ...
# 29282  4902.49929              3                 0       0    3            1
# 29567  4902.49929              3                 0       3    3            1
# 29644  4902.49929              3                 0       1    0            1
# 29822    18.94000              3                 0       3    3            1
# 29871  4902.49929              3                 0       6    0            1
# 30071  4902.49929              3                 0       6    3            1
# 30298    27.92000              3                 0       1    3            1
# 30560    26.23000              3                 0       6    0            2
# 30941    35.16000              3                 0       6    3            8
# 30966    19.53000              3                 0       6    2            1
#
#        ACCESS_SITE  ACCESS_METHOD  Radiation Dose   Procedure typeII  \
# 0               69              3          5147.0                  0
# 1               69              3          5798.0                  0
# 2               69              3          9762.0                  0
# 4               35              3          4845.0                  0
# 5               35              3          3064.0                  0
# 6               69              3          4153.0                  0
# 7               69              3          8978.0                  0
# 8               79              5          6312.0                  0
# 9               79              5          6521.0                  0
# 11              69              3          1143.0                  0
# ...            ...            ...             ...                ...
# 29282           35              3          8839.0                  0
# 29567           35              3          3816.0                  0
# 29644           35              3          1683.0                  0
# 29822           69              3          8059.0                  0
# 29871           35              3          3163.0                  0
# 30071           35              3          7515.0                  0
# 30298           35              3         13094.0                  0
# 30560           36              5          4564.0                  0
# 30941           85              5          2431.0                  0
# 30966           69              3          3920.0                  0
#
#        ARRHYTHMIA?  No. of Ablations?  No. Vessels Attempted  \
# 0               32                0.0               1.000000
# 1               32                0.0               1.000000
# 2               32                0.0               1.000000
# 4               32                0.0               1.000000
# 5               32                0.0               1.000000
# 6               32                0.0               1.000000
# 7               32                0.0               1.232419
# 8               32                0.0               1.000000
# 9               32                0.0               1.000000
# 11              32                0.0               1.000000
# ...            ...                ...                    ...
# 29282           32                0.0               1.000000
# 29567           32                0.0               3.000000
# 29644           32                0.0               1.232419
# 29822           32                0.0               1.000000
# 29871           32                0.0               1.232419
# 30071           32                0.0               1.000000
# 30298           32                0.0               3.000000
# 30560           32                0.0               1.232419
# 30941           32                0.0               1.000000
# 30966           32                0.0               1.000000
#
#        No. Chronic Occlusions Attempted  No. Lesions Attempted  \
# 0                              0.000000               1.000000
# 1                              0.000000               1.000000
# 2                              0.000000               1.000000
# 4                              0.000000               1.000000
# 5                              0.000000               1.000000
# 6                              0.000000               1.000000
# 7                              0.077323               1.281337
# 8                              0.000000               1.000000
# 9                              0.000000               1.000000
# 11                             0.000000               2.000000
# ...                                 ...                    ...
# 29282                          0.000000               3.000000
# 29567                          0.000000               2.000000
# 29644                          0.077323               1.281337
# 29822                          0.000000               1.000000
# 29871                          0.077323               1.281337
# 30071                          0.000000               1.000000
# 30298                          0.000000               2.000000
# 30560                          0.077323               1.281337
# 30941                          0.000000               1.000000
# 30966                          0.000000               1.000000
#
#        No. Lesions Successful  Largest balloon/Stent Used  \
# 0                    1.000000                    2.500000
# 1                    1.000000                    3.500000
# 2                    1.000000                    3.000000
# 4                    1.000000                    3.500000
# 5                    1.000000                    4.000000
# 6                    1.000000                    3.000000
# 7                    1.362211                    3.226638
# 8                    0.000000                    2.000000
# 9                    1.000000                    3.000000
# 11                   2.000000                    2.750000
# ...                       ...                         ...
# 29282                3.000000                    4.500000
# 29567                2.000000                    4.500000
# 29644                1.362211                    3.226638
# 29822                1.000000                    2.500000
# 29871                1.362211                    3.226638
# 30071                1.000000                    3.500000
# 30298                1.000000                    3.000000
# 30560                1.362211                    3.226638
# 30941                1.000000                    3.000000
# 30966                1.000000                    2.500000
#
#        No. of Restenosis attempted  No. Instent restenosis attempted  \
# 0                        23.000000                          0.000000
# 1                         0.000000                          0.000000
# 2                         0.000000                          0.000000
# 4                         0.000000                          0.000000
# 5                         0.000000                          0.000000
# 6                         0.000000                          0.000000
# 7                         0.030398                          0.042255
# 8                         0.000000                          0.000000
# 9                         0.000000                          0.000000
# 11                        0.000000                          0.000000
# ...                            ...                               ...
# 29282                     0.000000                          0.000000
# 29567                     0.000000                          0.000000
# 29644                     0.030398                          0.042255
# 29822                     0.000000                          0.000000
# 29871                     0.030398                          0.042255
# 30071                     0.000000                          0.000000
# 30298                     0.000000                          0.000000
# 30560                     0.030398                          0.042255
# 30941                     0.000000                          0.000000
# 30966                     0.000000                          0.000000
#
#        No. Stents Used  No. Drug Eluting Stents Used  \
# 0             1.000000                      1.000000
# 1             1.000000                      1.000000
# 2             2.000000                      2.000000
# 4             2.000000                      0.000000
# 5             1.000000                      0.000000
# 6             1.000000                      1.000000
# 7             1.375697                      1.212153
# 8             0.000000                      0.000000
# 9             1.000000                      1.000000
# 11            2.000000                      2.000000
# ...                ...                           ...
# 29282         3.000000                      0.000000
# 29567         2.000000                      2.000000
# 29644         1.375697                      1.212153
# 29822         1.000000                      1.000000
# 29871         1.375697                      1.212153
# 30071         1.000000                      1.000000
# 30298         2.000000                      2.000000
# 30560         1.375697                      1.212153
# 30941         1.000000                      1.000000
# 30966         1.000000                      1.000000
#
#        Longest Stent/Treated segment  OUTCOME  GENDER   Age  Ethnicity
# 0                          23.000000        1       1  52.0         17
# 1                          16.000000        1       1  53.0         17
# 2                          44.000000        1       0  51.0         17
# 4                          41.000000        1       1  77.0         17
# 5                          28.000000        1       1  67.0         17
# 6                          18.000000        1       1  48.0         17
# 7                          22.275609        1       1  69.0         17
# 8                          22.275609        1       0  86.0         17
# 9                          24.000000        1       1  60.0         17
# 11                         30.000000        1       1  57.0         17
# ...                              ...      ...     ...   ...        ...
# 29282                      24.000000        2       1  51.0         13
# 29567                      56.000000        2       1  82.0         17
# 29644                      22.275609        2       1  40.0         17
# 29822                      18.000000        2       1  85.0         17
# 29871                      22.275609        2       1  68.0         17
# 30071                      24.000000        2       1  84.0         13
# 30298                      30.000000        2       1  88.0         17
# 30560                      22.275609        2       1  70.0         17
# 30941                      24.000000        2       0  43.0         17
# 30966                      20.000000        2       0  97.0         13
#
# [2530 rows x 43 columns]

# %% [markdown]
# # Step 4 Feature Importances of Random Forest Tree
#
# The feature importances ranking as following:

# %%
# Out:
# Feature Importances:
# 1. Procedure Year (0.423118)
# 2. Procedure Quarter of year (0.083667)
# 3. Procedure Month (0.041721)
# 4. Procedure MonthNumber (0.041068)
# 5. Procedure Week of year (0.040501)
# 6. Procedure Day of Month (0.038533)
# 7. Day of Week (0.038416)
# 8. Time Waiting for Procedure (0.036290)
# 9. Procedure Group (0.022360)
# 10. Procedure TypeI (0.021566)
# 11. Booked Procedure (0.019270)
# 12. PREVIOUS_MI (0.015021)
# 13. PREVIOUS_CABG (0.013287)
# 14. PREVIOUS_PCI (0.011133)
# 15. RENAL_DISEASE (0.010737)
# 16. FAMILY_HIST_CAD (0.010492)
# 17. EJECTION_FRACTION_CAT (0.010352)
# 18. BMI (0.010306)
# 19. DIABETES_TYPE (0.010148)
# 20. DIABETES_CONTROL (0.009854)
# 21. Smoker (0.008302)
# 22. ACS (0.008187)
# 23. ACCESS_TYPE (0.008053)
# 24. ACCESS_SITE (0.008032)
# 25. ACCESS_METHOD (0.007349)
# 26. Radiation Dose (0.005894)
# 27.  Procedure typeII (0.005612)
# 28. ARRHYTHMIA? (0.005486)
# 29. No. of Ablations? (0.005348)
# 30. No. Vessels Attempted (0.004600)
# 31. No. Chronic Occlusions Attempted (0.003709)
# 32. No. Lesions Attempted (0.003273)
# 33. No. Lesions Successful (0.003214)
# 34. Largest balloon/Stent Used (0.003104)
# 35. No. of Restenosis attempted (0.002917)
# 36. No. Instent restenosis attempted (0.002821)
# 37. No. Stents Used (0.002200)
# 38. No. Drug Eluting Stents Used (0.001693)
# 39. Longest Stent/Treated segment (0.001296)
# 40. OUTCOME (0.000543)
# 41. GENDER (0.000389)
# 42. Age (0.000137)

# %% [markdown]
# # Step5 Random Forest Classifier predict
#
# Let select the features based on their importance. Predicted by Cross-Validation

# %%
nrtc_cv( 'OUTCOME' , var , data )
# Out:
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# (0.93823339585427334, array([ 1.,  1.,  1., ...,  1.,  1.,  0.]))

# %% [markdown]
# # CODE

# %%
# Import the data and output the null summary
from pandas import DataFrame
import pandas
from sklearn.ensemble import RandomForestClassifier
path = 'C:\\Users\\310249682\Documents\\data.xlsx'
data = pandas.read_excel(path)
pandas.set_option('display.max_columns',80)
pandas.set_option('display.max_rows',66)
NaN_count = [len(data[i])-data[i].count() for i in data.columns]
variable = [str([j.encode("utf-8") if type(j) is unicode else j for j in list(data[i].unique())]) for i in data.columns]
vtype = ['ID','ID','Numeric_int','categorical','categorical','Numeric_int','Categorical','Numeric_int','Categorical','Categorical',
         'Categorical','Categorical','Categorical','Categorical','Categorical','Categorical','Categorical','Categorical','Categorical','Numeric_int',
         'Categorical','Numeric_float','Numeric_float','Numeric_float','Numeric_float','Categorical','Categorical','Categorical','Numeric_int','Numeric_int',
         'Categorical','Categorical','Categorical','Categorical','Categorical','Categorical','Categorical','Categorical','Categorical','Categorical',
         'Numeric_int','Categorical','Categorical','Categorical','Categorical','Categorical','Categorical','Numeric_int','Numeric_int','Numeric_int',
         'Numeric_int','Numeric_int','Numeric_float','Numeric_int','Numeric_int','Numeric_int','Numeric_int','Numeric_int','Categorical','Categorical',
         'Categorical','Numeric_int','Categorical','Numeric_int','Categorical']
dtype = pandas.DataFrame(data = data.dtypes, columns = ['Type'])
dvtype = pandas.DataFrame(data = vtype, columns = ['variable type'],index = dtype.index)
dNaN = pandas.DataFrame(data = NaN_count, columns = ['Number of null'],index = dtype.index)
dvar = pandas.DataFrame(data = variable, columns = ['Items'],index = dtype.index)
frame=[dvtype,dNaN,dvar]
Nullsummary = pandas.concat(frame,axis=1)

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn import ensemble as ske
from sklearn.preprocessing import Imputer
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import cross_val_predict
import patsy
from numpy import float32
le = preprocessing.LabelEncoder()

# %%
#Function:Check the data type
def dattype( data ):
    ddtype = 'Error'
    data=data[pd.notnull(data)]
    for i in data:
        ddtype = type(i)
        break
    return ddtype
#convert the data
def typetransform ( data ):
    if dattype( data ) is unicode:
        le.fit( data )
        data = le.transform( data )
    else:
            imp = Imputer(missing_values='NaN', strategy='mean',axis = 1)
            imp.fit(data)
            data = imp.transform( data )
    return data
#delete the data
data = pd.read_excel('C:\\Users\\310249682\\Documents\\data1.xlsx')
del data['HISTORY_HYPERTENSION']
del data['TOTAL_CHOLESTEROL']
del data['CATH EVENTS']
del data['EJECTION_FRACTION']
del data['WEIGHT']
del data['HEIGHT']
del data['HEART_RATE']
del data['Euroscore']
del data['CLINICAL_SYNDROME']
del data['Indication for intervention']
del data['Presenting ECG']
del data['Thrombolysis']
del data['COMPLICATION']
del data['Replacement Device?']
del data['Replacement Reason']
del data['Device type']
del data['Device type.1']
del data['Indication for stent']
del data['LMS Protected']
del data['LENGTH_STAY_PROC_TO_DISCH']
del data['Patient_DB_ID']
del data['Procedure_Unique_Identifier']
#transform the data
for i in data.columns:
    if dattype( data[i] ) is unicode:
        data[i] = typetransform(data[i])
    else:
        data[i] = typetransform(data[i])[0]
# Out:
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\numpy\lib\arraysetops.py:200: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   flag = np.concatenate(([True], aux[1:] != aux[:-1]))
# C:\Ipython\Anaconda2\lib\site-packages\numpy\lib\arraysetops.py:259: FutureWarning: numpy equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   return aux[:-1][aux[1:] == aux[:-1]]
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
#balance the data with oversampling and undersampling
out_alive = data[data['OUTCOME'] == 1]
out_dead = data[data['OUTCOME'] == 2]
out_dead_new = pd.concat([out_dead]*5)
out_alive_new = out_alive[0:1265]
data_new = pd.concat([out_alive_new,out_dead_new])

# %%
#Random Forest Tree
outcome = 'OUTCOME'
predictors = data.columns
predictors = list(predictors)
del predictors[39]
data_training = data

data_training = data_training[data_training[outcome] != 3]
pre = data_training[predictors] #predictors dataframe
out = typetransform(data_training[outcome]) #outcome dataframe
out_array = np.asarray(out).ravel()
rfc = ske.RandomForestClassifier(n_estimators=1000) #random tree
scores = cross_val_score(rfc, pre, out_array)
pred = cross_val_predict(rfc,pre, out_array)

rfc2 = ske.RandomForestClassifier(n_estimators=1000).fit(pre,out_array)
feature_importance = rfc2.feature_importances_
# Out:
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
#Feature Importance
indices = np.argsort(feature_importance)[::-1]
print "Feature Importances:"
for f in range(42):
    print("%d. %s (%f)" % (f + 1, list(data.columns)[f],feature_importance[indices[f]]))
# Out:
# Feature Importances:
# 1. Procedure Year (0.423118)
# 2. Procedure Quarter of year (0.083667)
# 3. Procedure Month (0.041721)
# 4. Procedure MonthNumber (0.041068)
# 5. Procedure Week of year (0.040501)
# 6. Procedure Day of Month (0.038533)
# 7. Day of Week (0.038416)
# 8. Time Waiting for Procedure (0.036290)
# 9. Procedure Group (0.022360)
# 10. Procedure TypeI (0.021566)
# 11. Booked Procedure (0.019270)
# 12. PREVIOUS_MI (0.015021)
# 13. PREVIOUS_CABG (0.013287)
# 14. PREVIOUS_PCI (0.011133)
# 15. RENAL_DISEASE (0.010737)
# 16. FAMILY_HIST_CAD (0.010492)
# 17. EJECTION_FRACTION_CAT (0.010352)
# 18. BMI (0.010306)
# 19. DIABETES_TYPE (0.010148)
# 20. DIABETES_CONTROL (0.009854)
# 21. Smoker (0.008302)
# 22. ACS (0.008187)
# 23. ACCESS_TYPE (0.008053)
# 24. ACCESS_SITE (0.008032)
# 25. ACCESS_METHOD (0.007349)
# 26. Radiation Dose (0.005894)
# 27.  Procedure typeII (0.005612)
# 28. ARRHYTHMIA? (0.005486)
# 29. No. of Ablations? (0.005348)
# 30. No. Vessels Attempted (0.004600)
# 31. No. Chronic Occlusions Attempted (0.003709)
# 32. No. Lesions Attempted (0.003273)
# 33. No. Lesions Successful (0.003214)
# 34. Largest balloon/Stent Used (0.003104)
# 35. No. of Restenosis attempted (0.002917)
# 36. No. Instent restenosis attempted (0.002821)
# 37. No. Stents Used (0.002200)
# 38. No. Drug Eluting Stents Used (0.001693)
# 39. Longest Stent/Treated segment (0.001296)
# 40. OUTCOME (0.000543)
# 41. GENDER (0.000389)
# 42. Age (0.000137)

# %%
#CV score
var = [list(data.columns)[i] for i in list(indices[0:25])]
def nrtc_cv( outcome , predictors , data_training ):
    #transform training data
    pre = data_training[predictors] #predictors dataframe
    out = typetransform(data_training[outcome]) #outcome dataframe
    out_array = np.asarray(out).ravel()
    rfc = ske.RandomForestClassifier(n_estimators=1000) #random tree
    scores = cross_val_score(rfc, pre, out_array)
    pred = cross_val_predict(rfc,pre, out_array)
    return scores.mean(),pred
nrtc_cv( 'OUTCOME' , var , data )
# Out:
# C:\Ipython\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# (0.93581186007230566, array([ 1.,  1.,  1., ...,  1.,  1.,  0.]))
